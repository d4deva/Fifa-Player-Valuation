# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Fifa_data.csv")

# %%
df1=df.drop(['Unnamed: 0','Player_Name'],axis=1)

# %%
df1.isnull().sum()
# Out:
# Height              0
# Weight              0
# Age                 0
# Preferred_foot      0
# overall_score       0
# potential_score     0
# Ball_Skills         0
# Defence             0
# Mental              0
# Passing             0
# Physical            0
# Shooting            0
# Goalkeeping         0
# Weekly_Wage        62
# Market_Value       62
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#       Height  Weight  Age Preferred_foot  overall_score  potential_score  \
# 0        170      72   33           Left             93               93
# 1        187      83   35          Right             92               92
# 2        188      87   27          Right             91               93
# 3        181      70   29          Right             91               91
# 4        175      68   28          Right             91               91
# ...      ...     ...  ...            ...            ...              ...
# 2995     171      62   35           Left             73               73
# 2996     171      70   34           Left             73               73
# 2997     184      71   30           Left             73               73
# 2998     174      71   31           Left             73               73
# 2999     188      82   31          Right             73               73
#
#       Ball_Skills  Defence  Mental  Passing  Physical  Shooting  Goalkeeping  \
# ...

# %%
Preferred_foot = pd.get_dummies(df1.Preferred_foot, drop_first = True)

# %%
df2 = df1.drop(['Preferred_foot','Weekly_Wage'],axis=1)
df2.insert(5,'Preferred_foot',Preferred_foot)

# %%
df2.describe()
# Out:
#             Height       Weight          Age  overall_score  potential_score  \
# count  2938.000000  2938.000000  2938.000000    2938.000000      2938.000000
# mean    181.499319    76.264125    27.669163      76.519061        78.714091
# std       6.851071     7.257955     4.005972       3.363741         4.297176
# min     158.000000    56.000000    17.000000      73.000000        73.000000
# 25%     176.000000    71.000000    25.000000      74.000000        75.000000
# 50%     182.000000    76.000000    28.000000      75.000000        78.000000
# 75%     187.000000    81.000000    30.750000      78.000000        82.000000
# max     201.000000   103.000000    43.000000      93.000000        95.000000
#
#        Preferred_foot  Ball_Skills      Defence       Mental      Passing  \
# count     2938.000000  2938.000000  2938.000000  2938.000000  2938.000000
# mean         0.738938    67.991661    54.489687    65.475017    64.762747
# ...

# %%
df2.corr()
# Out:
#                    Height    Weight       Age  overall_score  potential_score  \
# Height           1.000000  0.784328  0.065545       0.053536         0.045745
# Weight           0.784328  1.000000  0.171122       0.066597        -0.028080
# Age              0.065545  0.171122  1.000000       0.069449        -0.498331
# overall_score    0.053536  0.066597  0.069449       1.000000         0.710242
# potential_score  0.045745 -0.028080 -0.498331       0.710242         1.000000
# Preferred_foot   0.108379  0.106853  0.077827       0.017079        -0.014482
# Ball_Skills     -0.511411 -0.477780 -0.169589       0.113025         0.130425
# Defence         -0.067467 -0.089166 -0.052689       0.030495         0.030579
# Mental          -0.276595 -0.251583 -0.015935       0.212968         0.124088
# Passing         -0.492369 -0.462260 -0.101879       0.150119         0.110945
# Physical        -0.513492 -0.429325 -0.267596       0.124470         0.190073
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 10))
corr = df2.corr()
sns.heatmap(corr,square=True, ax=ax,cmap= 'RdYlGn', linewidths=0.50, linecolor='black',annot=True)
plt.show()

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(df2, figsize = (15,15),s=10, marker = 'D')
plt.show()

# %%
sns.pairplot(df2)
plt.show()

# %%
df2.plot(kind='density', subplots=True, layout=(4,4),fontsize=1, figsize=(15,15),sharex=False, legend=True,)
plt.show()

# %%
df2.Market_Value.skew()
# Out:
# 3.5519667765096647

# %%
market_value_transformed=np.log(df2.Market_Value)
market_value_transformed.skew()
# Out:
# -0.3313669405652935

# %%
X= df2.drop("Market_Value",axis=1)
y= market_value_transformed

# %% [markdown]
# ## Model 1: Linear regression model

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
seed = 50
test_size = 0.20
trainingSet, testingSet = train_test_split(df2, test_size = test_size, random_state = seed)

# %%
df2.columns
# Out:
# Index(['Height', 'Weight', 'Age', 'overall_score', 'potential_score',
#        'Preferred_foot', 'Ball_Skills', 'Defence', 'Mental', 'Passing',
#        'Physical', 'Shooting', 'Goalkeeping', 'Market_Value'],
#       dtype='object')

# %%
lm = smf.ols(formula = "Market_Value ~ Height+Weight+Age+overall_score+potential_score+Preferred_foot+Ball_Skills+Defence+Mental+Passing+Physical+Shooting+Goalkeeping", data = trainingSet)
model_1 = lm.fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Market_Value   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     710.7
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):               0.00
# Time:                        16:47:30   Log-Likelihood:                -40359.
# No. Observations:                2350   AIC:                         8.075e+04
# Df Residuals:                    2336   BIC:                         8.083e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -2.613e+08   7.05e+06    -37.061      0.000   -2.75e+08   -2.48e+08
# ...

# %%
lm = smf.ols(formula = "Market_Value ~ Age+overall_score+potential_score+Ball_Skills+Defence+Mental+Passing+Physical+Shooting+Goalkeeping", data = trainingSet)
model_1 = lm.fit()
print(model_1.summary())
